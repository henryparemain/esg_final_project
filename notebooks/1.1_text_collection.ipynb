# %% [markdown]
# # 1.1_text_collection

# %% [markdown]
# The following notebook goes through the process of text collection. The high level sequence is as follows:
#
# 1. Obtain a list of companies to scrape reports for
# 2. Obtain a bank of urls for each report using a webscraper
# 3. Extract raw text from the pdfs and place in a dataframe

# %% [markdown]
# ### Package Imports

# %%
# general imports
import pandas as pd
import numpy as np
import capstone_utility_functions as cuf
import seaborn as sns
import matplotlib.pyplot as plt

# webscraping imports
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests

# misc imports
import joblib
import re
import io 
from PyPDF2 import PdfReader

# %% [markdown]
# The following urls are the 3 separate landing pages for NYSE, NASDAQ and LSE, which are to be used in the following section. This will ulimtately allow us to iterate through the 3 landing pages and grab the company names and tickers for each page. This then gives a list of companies which we know exist on ResponsibilityReports.com, which can be used in the following section to extract pdf urls for.

# %% [markdown]
# ### ESG Report Collection

# %%
#NYSE url
'https://www.responsibilityreports.com/Companies?exch=1'
#NASDAQ url
'https://www.responsibilityreports.com/Companies?exch=2'
#LSE url
'https://www.responsibilityreports.com/Companies?exch=9'

exchange_urls = ['https://www.responsibilityreports.com/Companies?exch=1',
                 'https://www.responsibilityreports.com/Companies?exch=2',
                 'https://www.responsibilityreports.com/Companies?exch=9']

# %% [markdown]
# The below cell is the webscraper. Note it can take a long time to run - advised to load pickles (see below) instead!

# %%
# #initialise lists and dictionaries
# missing_ticker = []
# report_bank = {}
# tick_bank = {}
# #initialise counter to see how far through for loop we are
# count = 0
# #iterate through list of relevant urls for each exchange.
# for exchange in exchange_urls:
#     #Obtain list of company names for exchange X
#     company_names = cuf.get_exchange_companylist(exchange)
#     #obtain list of url-friendly company names
#     company_names_url_compatible = cuf.get_exchange_company_list_url_compatible(company_names)
#     #Iterate through list of company names one at a time to ultimately get ESG report url
#     for name,url_name in zip(company_names,company_names_url_compatible) :
#         try:
#             #obtain html from first landing page of specific company 
#             soup1 = cuf.html_parse('https://www.responsibilityreports.com/Companies?search='+ url_name)
#             a_href=soup1.find_all('span', class_ = 'companyName')
#             links = soup1.find_all('a', href=True)
#         except Exception as e:
#             print(e)
#             print(name)
#         #form url for second landing page where reports are found for a specific country 
#         for link in links:
#             url_ext= link['href']
#             #obtain all labels for href tags to find the url extension
#             label = link.text
#             #finding the label which contains the company name 
#             if name in label:
#                 search_2_extension = url_ext
#                 # building the url for the page which contains all reports 
#                 search_2_url = 'https://www.responsibilityreports.com' + search_2_extension
#                 break
#             else:
#                 search_2_url = None

#         #obtain html from second landing page
#         try:
#             soup2 = cuf.html_parse(search_2_url)
#         except Exception as e:
#             print(f'No link for {name}')
#             print(e)
#             continue
        
#         #initialise list where  middle part of url (eg NASDAQ_AAPL_) will be stored, to ultimately append to final pdf url.
#         middle = []

#         for a in soup2.find_all('a', href=True):
#             str = a['href']
#             #regex to find the exchange symbol and company ticker from within the html soup eg NASDAQ_AAPL_
#             exchange_pattern = r'\b[A-Z]{0,10}_[A-Z]{0,10}_'
#             #regex to find the year of the latest report from the html soup 
#             latest_year_pattern = r'\d{4}'
#             #search the html for the relevant exchange and ticker
#             found_exchange = re.findall(exchange_pattern,str)
#             #find the year of the latest annual report from the html
#             found_year = re.findall(latest_year_pattern,str)
#             if len(found_exchange)>0:
#                 middle.append(found_exchange)
#                 break
#         #obtaining respective ticker from url
#         pattern = r'Company\/(.)'
#         #used in line 73 to add a unique tag to report_url, based on the first letter of the ticker. 
#         extract = re.findall(pattern,search_2_url)
#         try:
#             #checking if the most recent report is 2021 or not. If not the latest, 
#             #then the base url changes to account for the Archive.
#             if int(found_year[0]) < 2021:
#                 report_url_base = 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/'
#                 report_url_final = report_url_base + middle[0][0] + '2021.pdf'
#             else:
#                 report_url_base = 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/'
#                 report_url_final = report_url_base + extract[0].lower() +'/'+ middle[0][0] + '2021.pdf'

#         except:
#             continue
#         #adding ticker to dictionary
#         tick_pattern = r'_(.+)_'
#         tick = re.findall(tick_pattern,middle[0][0])
#         tick_bank[name] = tick
#         #appending report url and company name to report_bank dictionary
#         report_bank[name] = report_url_final
#         count += 1
#         print(count)

# %%
#pickling the report_bank dictionary to ensure that the above scraper does not need to be run again (30min+)
#report_bank_dict = joblib.dump(report_bank, '../data/report_bank_dict.pkl')

# %%
tick_bank_list = joblib.load('../data/tick_bank_dict.pkl')
len(tick_bank_list)
# Out:
# 1255

# %% [markdown]
# Successfully retrieved urls for 1255 pdfs. The company name and report link are stored in the report_bank dictionary below.

# %%
report_bank = joblib.load('../data/report_bank_dict.pkl')

# %%
report_bank
# Out:
# {'3M Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/3/NYSE_MMM_2021.pdf',
#  'ABB Ltd': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_ABB_2021.pdf',
#  'Abbott Laboratories': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ABT_2021.pdf',
#  'Abbvie Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ABBV_2021.pdf',
#  'ABM Industries, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ABM_2021.pdf',
#  'Acadia Realty Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AKR_2021.pdf',
#  'Accenture plc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ACN_2021.pdf',
#  'ACCO Brands': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ACCO_2021.pdf',
#  'Acuity Brands, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AYI_2021.pdf',
#  'Adient Plc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_ADNT_2021.pdf',
#  'Adtalem Global Education Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ATGE_2021.pdf',
#  'Advance Auto Parts Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AAP_2021.pdf',
#  'Advanced Drainage Systems Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_WMS_2021.pdf',
#  'Advansix': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ASIX_2021.pdf',
#  'AECOM Technology Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ACM_2021.pdf',
#  'AFLAC Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AFL_2021.pdf',
#  'AGCO Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AGCO_2021.pdf',
#  'Agilent Technologies Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_A_2021.pdf',
#  'Agree Realty Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ADC_2021.pdf',
#  'Air Lease Corp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AL_2021.pdf',
#  'Air Products & Chemicals Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_APD_2021.pdf',
#  'Alamo Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ALG_2021.pdf',
#  'Alaska Air Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ALK_2021.pdf',
#  'Albemarle Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ALB_2021.pdf',
#  'Albertsons Companies, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ACI_2021.pdf',
#  'Alcoa Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AA_2021.pdf',
#  'Alexander & Baldwin, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ALEX_2021.pdf',
#  'Alexandria Real Estate Equities, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ARE_2021.pdf',
#  'Alibaba Group Holding Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_BABA_2021.pdf',
#  'Allegheny Technologies Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ATI_2021.pdf',
#  'Allergan plc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AGN_2021.pdf',
#  'ALLETE Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ALE_2021.pdf',
#  'Alliance Data Systems Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ADS_2021.pdf',
#  'Allianz SE': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AZ_2021.pdf',
#  'Allstate Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ALL_2021.pdf',
#  'Ally Financial Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ALLY_2021.pdf',
#  'Altria Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_MO_2021.pdf',
#  'Aluminum Corporation of China Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ACH_2021.pdf',
#  'Ambev S.A.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ABEV_2021.pdf',
#  'Amdocs Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DOX_2021.pdf',
#  'Ameren Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AEE_2021.pdf',
#  'Ameresco Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AMRC_2021.pdf',
#  'America Movil, S.A.B. de C.V.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AMX_2021.pdf',
#  'American Assets Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AAT_2021.pdf',
#  'American Axle & Manufacturing Holdings Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AXL_2021.pdf',
#  'American Campus Communities Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ACC_2021.pdf',
#  'American Electric Power Company, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_AEP_2021.pdf',
#  'American Express Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AXP_2021.pdf',
#  'American Financial Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AFG_2021.pdf',
#  'American Homes 4 Rent': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AMH_2021.pdf',
#  'American International Group, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AIG_2021.pdf',
#  'American States Water Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AWR_2021.pdf',
#  'American Tower Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AMT_2021.pdf',
#  'American Water Works Company, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AWK_2021.pdf',
#  'Americold Realty Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_COLD_2021.pdf',
#  'Ameriprise Financial Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AMP_2021.pdf',
#  'Amerisourcebergen Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_ABC_2021.pdf',
#  'Ametek Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AME_2021.pdf',
#  'AMN Healthcare Services Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AMN_2021.pdf',
#  'Amneal Pharmaceuticals, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AMRX_2021.pdf',
#  'Amphenol Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_APH_2021.pdf',
#  'AngloGold Ashanti Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AU_2021.pdf',
#  'Anixter International Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AXE_2021.pdf',
#  'Annaly Capital Management, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_NLY_2021.pdf',
#  'Antero Midstream Partners LP': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AM_2021.pdf',
#  'Antero Resources Corp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AR_2021.pdf',
#  'Anywhere Real Estate Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_HOUS_2021.pdf',
#  'AO Smith Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AOS_2021.pdf',
#  'Aon Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AON_2021.pdf',
#  'Apache Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_APA_2021.pdf',
#  'Apartment Investment and Management Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AIV_2021.pdf',
#  'Apollo Global Management, LLC': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_APO_2021.pdf',
#  'Aptar Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ATR_2021.pdf',
#  'Aptiv': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_APTV_2021.pdf',
#  'Aramark': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_ARMK_2021.pdf',
#  'Archer Daniels Midland Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ADM_2021.pdf',
#  'Archrock Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_AROC_2021.pdf',
#  'Arconic Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ARNC_2021.pdf',
#  'Arcosa, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ACA_2021.pdf',
#  'Ardagh Group Sa': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ARD_2021.pdf',
#  'Arista Networks Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ANET_2021.pdf',
#  'Armada Hoffler Properties Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AHH_2021.pdf',
#  'Arrow Electronics Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ARW_2021.pdf',
#  'Arthur J Gallagher & Co.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AJG_2021.pdf',
#  'ASE Technology Holding Co., Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ASX_2021.pdf',
#  'ASGN Incorporated': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ASGN_2021.pdf',
#  'Ashland Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ASH_2021.pdf',
#  'Assurant Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_AIZ_2021.pdf',
#  'AT&T Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_T_2021.pdf',
#  'Athene Holding Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ATH_2021.pdf',
#  'Atkore International Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_ATKR_2021.pdf',
#  'Atmos Energy Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ATO_2021.pdf',
#  'Autoliv Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ALV_2021.pdf',
#  'Automatic Data Processing Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ADP_2021.pdf',
#  'AutoZone Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AZO_2021.pdf',
#  'AvalonBay Communities Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AVB_2021.pdf',
#  'Avanos Medical, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AVNS_2021.pdf',
#  'Avantor, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/a/NYSE_AVTR_2021.pdf',
#  'Avaya Holdings Corp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AVYA_2021.pdf',
#  'Avient Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AVNT_2021.pdf',
#  'Avnet, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AVT_2021.pdf',
#  'Avon Products, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AVP_2021.pdf',
#  'Azure Power Global Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AZRE_2021.pdf',
#  'Badger Meter Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BMI_2021.pdf',
#  'Baker Hughes Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BKR_2021.pdf',
#  'Ball Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BLL_2021.pdf',
#  'Bank of New York Mellon': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BK_2021.pdf',
#  'Barnes Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_B_2021.pdf',
#  'Bausch Health Companies Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BHC_2021.pdf',
#  'Baxter International Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BAX_2021.pdf',
#  'Baytex Energy Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BTE_2021.pdf',
#  'BCE Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BCE_2021.pdf',
#  'Becton, Dickinson and Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BDX_2021.pdf',
#  'Benchmark Electronics Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/b/NYSE_BHE_2021.pdf',
#  'Berry Global Group Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BERY_2021.pdf',
#  'Best Buy': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/b/NYSE_BBY_2021.pdf',
#  'BEST Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BEST_2021.pdf',
#  'BHP Billiton Ltd': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BHP_2021.pdf',
#  'Bio-Rad Laboratories': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BIO_2021.pdf',
#  'Black Hills Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BKH_2021.pdf',
#  'Black Knight Financial Services, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BKI_2021.pdf',
#  'Boeing Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/b/NYSE_BA_2021.pdf',
#  'Booz Allen Hamilton': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BAH_2021.pdf',
#  'BorgWarner': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/b/NYSE_BWA_2021.pdf',
#  'Boston Properties Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BXP_2021.pdf',
#  'Boston Scientific Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BSX_2021.pdf',
#  'Boyd Gaming Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BYD_2021.pdf',
#  'Brandywine Realty Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BDN_2021.pdf',
#  'Brasilagro Cia Brasileira De Propriedades Agricolas': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_LND_2021.pdf',
#  'BrightView Holdings, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/b/NYSE_BV_2021.pdf',
#  'Bristol Myers Squibb Co.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BMY_2021.pdf',
#  'Brixmor Property Group Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BRX_2021.pdf',
#  'Broadridge Financial Solutions Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BR_2021.pdf',
#  'Brookdale Senior Living Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BKD_2021.pdf',
#  'Brookfield Asset Management Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BAM_2021.pdf',
#  'Brunswick Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BC_2021.pdf',
#  'Bunge Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/b/NYSE_BG_2021.pdf',
#  'Burlington Stores Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_BURL_2021.pdf',
#  'BWX Technologies Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/b/NYSE_BWXT_2021.pdf',
#  'Cabot Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CBT_2021.pdf',
#  'Cal-Maine Foods, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CALM_2021.pdf',
#  'California Resources Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CRC_2021.pdf',
#  'California Water Service Group': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CWT_2021.pdf',
#  'Callon Petroleum Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CPE_2021.pdf',
#  'Camden Property Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CPT_2021.pdf',
#  'Campbell Soup Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NYSE_CPB_2021.pdf',
#  'Cannae Holdings, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CNNE_2021.pdf',
#  'Canon, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NYSE_CAJ_2021.pdf',
#  'Cantel Medical Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CMN_2021.pdf',
#  'Capital One Financial Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_COF_2021.pdf',
#  'Capri Holdings Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NYSE_CPRI_2021.pdf',
#  'Cardinal Health Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NYSE_CAH_2021.pdf',
#  'Carlisle Companies Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CSL_2021.pdf',
#  'CarMax Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NYSE_KMX_2021.pdf',
#  'Carnival Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CCL_2021.pdf',
#  'Catalent Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NYSE_CTLT_2021.pdf',
#  'Catchmark Timber Trust Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CTT_2021.pdf',
#  'Caterpillar Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CAT_2021.pdf',
#  'CB Richard Ellis Group, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CBRE_2021.pdf',
#  'CBIZ Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CBZ_2021.pdf',
#  'CBRE Group Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CBRE_2021.pdf',
#  'Celestica Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CLS_2021.pdf',
#  'CenterPoint Energy Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CNP_2021.pdf',
#  'CF Industries Holdings, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CF_2021.pdf',
#  'CGI Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GIB_2021.pdf',
#  'Chesapeake Energy Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CHK_2021.pdf',
#  'Chevron Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CVX_2021.pdf',
#  'China Mobile Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CHL_2021.pdf',
#  'China Petroleum & Chemical Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_SNP_2021.pdf',
#  'China Southern Airlines Company Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ZNH_2021.pdf',
#  'Chipotle Mexican Grill Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CMG_2021.pdf',
#  'Choice Hotels International Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CHH_2021.pdf',
#  'Chubb Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CB_2021.pdf',
#  'Chunghwa Telecom Co., Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CHT_2021.pdf',
#  'Church & Dwight Co. Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CHD_2021.pdf',
#  'Ciena Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CIEN_2021.pdf',
#  'CIGNA Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CI_2021.pdf',
#  'Ciner Resources LP': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CINR_2021.pdf',
#  'CIT Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CIT_2021.pdf',
#  'Citigroup Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_C_2021.pdf',
#  'Citizens Financial Group': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CFG_2021.pdf',
#  'City Office Reit': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CIO_2021.pdf',
#  'Civeo Corp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CVEO_2021.pdf',
#  'Clean Harbors Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CLH_2021.pdf',
#  'Clearwater Paper Corp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CLW_2021.pdf',
#  'Clearway Energy, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CWEN_2021.pdf',
#  'Cliffs Natural Resources Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CLF_2021.pdf',
#  'CMS Energy Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CMS_2021.pdf',
#  'CNH Industrial N.V.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CNHI_2021.pdf',
#  'CNO Financial Group, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CNO_2021.pdf',
#  'CNX Resources': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CNX_2021.pdf',
#  'Coca Cola': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_KO_2021.pdf',
#  'Coeur Mining Inc. ': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CDE_2021.pdf',
#  'Colgate-Palmolive Co.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CL_2021.pdf',
#  'Columbia Property Trust Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CXP_2021.pdf',
#  'Comerica': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CMA_2021.pdf',
#  'Commercial Metals Co.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CMC_2021.pdf',
#  'Community Health Systems Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CYH_2021.pdf',
#  'Companhia de saneamento Basico Do Estado De Sao Paulo - Sabesp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_SBS_2021.pdf',
#  'Compass Minerals International Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CMP_2021.pdf',
#  'Conagra Brands, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CAG_2021.pdf',
#  'Conduent Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CNDT_2021.pdf',
#  'ConocoPhillips': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_COP_2021.pdf',
#  'Consol Energy Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CEIX_2021.pdf',
#  'Consolidated Edison, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ED_2021.pdf',
#  'Constellation Brands': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NYSE_STZ_2021.pdf',
#  'Constellium SE': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CSTM_2021.pdf',
#  'Continental Resources Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CLR_2021.pdf',
#  'Controladora Vuela Co Avcn SA CV': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_VLRS_2021.pdf',
#  'Cooper Tire & Rubber': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CTB_2021.pdf',
#  'Cooper-Standard Holdings Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CPS_2021.pdf',
#  'Copa Holdings Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CPA_2021.pdf',
#  'Core Laboratories': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CLB_2021.pdf',
#  'Corecivic Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CXW_2021.pdf',
#  'CoreSite Realty Corp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_COR_2021.pdf',
#  'Corporate Office Properties Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_OFC_2021.pdf',
#  'Cousins Properties': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CUZ_2021.pdf',
#  'Covanta Holding Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NYSE_CVA_2021.pdf',
#  'Covia Holdings Corp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CVIA_2021.pdf',
#  'Credit Suisse Group': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CS_2021.pdf',
#  'Crescent Energy': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CRGY_2021.pdf',
#  'Crown Castle International': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CCI_2021.pdf',
#  'Crown Holdings': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CCK_2021.pdf',
#  'CubeSmart': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CUBE_2021.pdf',
#  'Cummins, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CMI_2021.pdf',
#  'Cushman & Wakefield Plc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CWK_2021.pdf',
#  'CVS Health': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_CVS_2021.pdf',
#  'Dana Incorporated': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DAN_2021.pdf',
#  'Danaher Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NYSE_DHR_2021.pdf',
#  'Darling Ingredients Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NYSE_DAR_2021.pdf',
#  'Deere & Co.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NYSE_DE_2021.pdf',
#  'Delek US Holdings Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DK_2021.pdf',
#  'Dell Technologies Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NYSE_DELL_2021.pdf',
#  'Delphi': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DPH_2021.pdf',
#  'Delta Air Lines Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DAL_2021.pdf',
#  'Denbury Resources Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NYSE_DNR_2021.pdf',
#  'Devon Energy Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NYSE_DVN_2021.pdf',
#  "Dick's Sporting Goods Inc.": 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DKS_2021.pdf',
#  'Diebold Nixdorf, Incorporated': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DBD_2021.pdf',
#  'Digital Realty Trust Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DLR_2021.pdf',
#  'DigitalBridge': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DBRG_2021.pdf',
#  'Dillards Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DDS_2021.pdf',
#  'Discover Financial Services': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DFS_2021.pdf',
#  'Dole plc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DOLE_2021.pdf',
#  'Dominion Energy, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_D_2021.pdf',
#  "Domino's Pizza, Inc.": 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DPZ_2021.pdf',
#  'Donaldson Company Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DCI_2021.pdf',
#  'Douglas Emmett Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DEI_2021.pdf',
#  "Dr. Reddy's Laboratories Ltd": 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_RDY_2021.pdf',
#  'DTE Energy Co.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NYSE_DTE_2021.pdf',
#  'Duke Energy Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DUK_2021.pdf',
#  'Duke Realty Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DRE_2021.pdf',
#  'Dun & Bradstreet Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DNB_2021.pdf',
#  'DuPont': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NYSE_DD_2021.pdf',
#  'DXC Technology': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DXC_2021.pdf',
#  'E2open': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/e/NYSE_ETWO_2021.pdf',
#  'EastGroup Properties': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EGP_2021.pdf',
#  'Eastman Chemical Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EMN_2021.pdf',
#  'Eaton Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ETN_2021.pdf',
#  'Ecolab Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ECL_2021.pdf',
#  'Edgewell Personal Care Co': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EPC_2021.pdf',
#  'Edison International': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EIX_2021.pdf',
#  'Edwards Lifesciences': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EW_2021.pdf',
#  'El Paso Electric Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EE_2021.pdf',
#  'Elanco Animal Health Incorporated': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ELAN_2021.pdf',
#  'Element Solutions': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ESI_2021.pdf',
#  'Eli Lilly & Co.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_LLY_2021.pdf',
#  'EMCOR Group': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EME_2021.pdf',
#  'Emergent BioSolutions, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EBS_2021.pdf',
#  'Enel Chile S.A.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ENIC_2021.pdf',
#  'Energizer Holdings Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ENR_2021.pdf',
#  'ENI S.p.A.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_E_2021.pdf',
#  'EnLink Midstream, LLC': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ENLC_2021.pdf',
#  'EnPro Industries': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_NPO_2021.pdf',
#  'Enterprise Products Partners L.P.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EPD_2021.pdf',
#  'Enviva Partners LP': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EVA_2021.pdf',
#  'EOG Resources': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EOG_2021.pdf',
#  'EQT Corp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EQT_2021.pdf',
#  'Equitrans Midstream Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ETRN_2021.pdf',
#  'Equity Lifestyles Properties Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ELS_2021.pdf',
#  'Equity Residential': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EQR_2021.pdf',
#  'ESCO Technologies Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ESE_2021.pdf',
#  'Essent Group Ltd': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/e/NYSE_ESNT_2021.pdf',
#  'Essential Utilities Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_WTRG_2021.pdf',
#  'Essex Property Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ESS_2021.pdf',
#  'Estee Lauder Companies Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EL_2021.pdf',
#  'EuroNav': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EURN_2021.pdf',
#  'Everest Re Group Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_RE_2021.pdf',
#  'Evergy Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EVRG_2021.pdf',
#  'Eversource Energy': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ES_2021.pdf',
#  'Evertec Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EVTC_2021.pdf',
#  'Evoqua Water Technologies': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_AQUA_2021.pdf',
#  'Exelon Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EXC_2021.pdf',
#  'Exterran Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EXTN_2021.pdf',
#  'Extra Space Storage Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_EXR_2021.pdf',
#  'Exxon Mobil Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_XOM_2021.pdf',
#  'F.N.B. Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/f/NYSE_FNB_2021.pdf',
#  'FactSet Research Systems Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FDS_2021.pdf',
#  'Federal Realty Investment Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FRT_2021.pdf',
#  'Federal Signal Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/f/NYSE_FSS_2021.pdf',
#  'FedEx Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/f/NYSE_FDX_2021.pdf',
#  'Fiat Chrysler Automobiles N.V.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FCAU_2021.pdf',
#  'Fidelity National Financial Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FNF_2021.pdf',
#  'First American Financial Corp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FAF_2021.pdf',
#  'First Horizon National Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FHN_2021.pdf',
#  'First Industrial Realty Trust Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FR_2021.pdf',
#  'First Republic Bank': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FRC_2021.pdf',
#  'Flagstar Bancorp Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FBC_2021.pdf',
#  'Fleetcor Tech': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FLT_2021.pdf',
#  'FLEX LNG Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FLNG_2021.pdf',
#  'Flowers Foods Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FLO_2021.pdf',
#  'Flowserve Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FLS_2021.pdf',
#  'Fluor Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FLR_2021.pdf',
#  'FMC Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FMC_2021.pdf',
#  'Fomento Economico Mexicano S.A.B. de C.V.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FMX_2021.pdf',
#  'Ford Motor Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_F_2021.pdf',
#  'Fortive Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/f/NYSE_FTV_2021.pdf',
#  'Fortune Brands Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FBHS_2021.pdf',
#  'Franklin Street Properties Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FSP_2021.pdf',
#  'Freeport-McMoRan Copper & Gold Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FCX_2021.pdf',
#  'Fresh Del Monte Produce Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FDP_2021.pdf',
#  'FTI Consulting  Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FCN_2021.pdf',
#  'FTS International Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FTSI_2021.pdf',
#  'GAM Holding AG': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GAM_2021.pdf',
#  'Gap Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GPS_2021.pdf',
#  'Gartner, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_IT_2021.pdf',
#  'GasLog Ltd': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GLOG_2021.pdf',
#  'GasLog Partners LP': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GLOP_2021.pdf',
#  'Gates Industrial Corporation plc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GTES_2021.pdf',
#  'General Dynamics Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GD_2021.pdf',
#  'General Mills, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/g/NYSE_GIS_2021.pdf',
#  'General Motors': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GM_2021.pdf',
#  'Genuine Parts': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/g/NYSE_GPC_2021.pdf',
#  'Gildan Activewear Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GIL_2021.pdf',
#  'Glaukos Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GKOS_2021.pdf',
#  'Global Payments Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/g/NYSE_GPN_2021.pdf',
#  'Globe Life Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GL_2021.pdf',
#  'Goldman Sachs Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GS_2021.pdf',
#  'Goodyear Tire & Rubber Co.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GT_2021.pdf',
#  'GrafTech International Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GTI_2021.pdf',
#  'Granite Construction Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GVA_2021.pdf',
#  'Graphic Packaging Holding Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GPK_2021.pdf',
#  'Greenbrier Companies': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GBX_2021.pdf',
#  'Greif Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GEF_2021.pdf',
#  'Grupo Supervielle S.A.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_SUPV_2021.pdf',
#  'Grupo Televisa S.A.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_TV_2021.pdf',
#  'Guangshen Railway Company Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GSH_2021.pdf',
#  'Guess? Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_GES_2021.pdf',
#  'H & R Block Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HRB_2021.pdf',
#  'Hannon Armstrong Sustainable Infrastructure Capital, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HASI_2021.pdf',
#  'Harley-Davidson, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HOG_2021.pdf',
#  'Harsco Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HSC_2021.pdf',
#  'Hartford Financial Services Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HIG_2021.pdf',
#  'Hasbro Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HAS_2021.pdf',
#  'Hawaiian Electric Industries Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/h/NYSE_HE_2021.pdf',
#  'HB Fuller Co': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_FUL_2021.pdf',
#  'HDFC Bank Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HDB_2021.pdf',
#  'Healthcare Realty Trust Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HR_2021.pdf',
#  'Healthcare Trust of America inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HTA_2021.pdf',
#  'Healthpeak Properties Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_PEAK_2021.pdf',
#  'Hecla Mining Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HL_2021.pdf',
#  'Helix Energy Solutions Group, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HLX_2021.pdf',
#  'Helmerich & Payne, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/h/NYSE_HP_2021.pdf',
#  'Herbalife Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HLF_2021.pdf',
#  'Hersha Hospitality Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HT_2021.pdf',
#  'Hess Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HES_2021.pdf',
#  'Hewlett Packard Enterprise Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HPE_2021.pdf',
#  'Hexcel Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HXL_2021.pdf',
#  'Highwoods Properties Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HIW_2021.pdf',
#  'Hillenbrand, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HI_2021.pdf',
#  'Hilton Worldwide Holdings, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HLT_2021.pdf',
#  'HNI Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HNI_2021.pdf',
#  'HollyFrontier Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HFC_2021.pdf',
#  'Honeywell International Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HON_2021.pdf',
#  'Horace Mann Educators Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HMN_2021.pdf',
#  'Hormel Foods Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HRL_2021.pdf',
#  'Host Hotels & Resorts Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/h/NYSE_HST_2021.pdf',
#  'Howmet Aerospace Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HWM_2021.pdf',
#  'Hubbell Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/h/NYSE_HUBB_2021.pdf',
#  'Humana Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HUM_2021.pdf',
#  'Huntington': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HBAN_2021.pdf',
#  'Huntsman Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HUN_2021.pdf',
#  'Hyatt Hotels Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_H_2021.pdf',
#  'Hyster-Yale Materials Handling': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_HY_2021.pdf',
#  'IAMGOLD Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_IAG_2021.pdf',
#  'IDACORP': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_IDA_2021.pdf',
#  'IDEX Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_IEX_2021.pdf',
#  'IHS Markit': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_INFO_2021.pdf',
#  'Illinois Tool Works': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_ITW_2021.pdf',
#  'Industrias Bachoco, S.A. de C.V.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_IBA_2021.pdf',
#  'Infosys Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_INFY_2021.pdf',
# ...
#  'CME Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CME_2021.pdf',
#  'Cohu Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_COHU_2021.pdf',
#  'Columbia Sportswear Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_COLM_2021.pdf',
#  'Comcast Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CMCSA_2021.pdf',
#  'Commerce Bancshares Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CBSH_2021.pdf',
#  'Commscope Holdings': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_COMM_2021.pdf',
#  'CommVault Systems, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NASDAQ_CVLT_2021.pdf',
#  'Consolidated Communications Holdings, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CNSL_2021.pdf',
#  'Costco Wholesale Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_COST_2021.pdf',
#  'Coupa Software Incorporated': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NASDAQ_COUP_2021.pdf',
#  'Cracker Barrel Old Country Store, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CBRL_2021.pdf',
#  'Craft Brew Alliance Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_BREW_2021.pdf',
#  'Cree, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CREE_2021.pdf',
#  'Crestwood Equity Partners LP': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CEQP_2021.pdf',
#  'Criteo': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CRTO_2021.pdf',
#  'Cross Country Healthcare': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CCRN_2021.pdf',
#  'CSX Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CSX_2021.pdf',
#  'Cumberland Pharmaceuticals': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_CPIX_2021.pdf',
#  'CyrusOne Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/c/NASDAQ_CONE_2021.pdf',
#  'Deckers Outdoor Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_DECK_2021.pdf',
#  'Dentsply Sirona Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_XRAY_2021.pdf',
#  'DexCom, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_DXCM_2021.pdf',
#  'Diamondback Energy, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NASDAQ_FANG_2021.pdf',
#  'Diodes Incorporated': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_DIOD_2021.pdf',
#  'Dollar Tree, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/d/NASDAQ_DLTR_2021.pdf',
#  'Dunkin Brands Group': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_DNKN_2021.pdf',
#  'Eagle Bulk Shipping Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_EGLE_2021.pdf',
#  'eBay': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_EBAY_2021.pdf',
#  'Elbit Systems Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_ESLT_2021.pdf',
#  'Energy Recovery': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_ERII_2021.pdf',
#  'Enphase Energy Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_ENPH_2021.pdf',
#  'Equinix, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_EQIX_2021.pdf',
#  'Establishment Labs Holdings Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_ESTA_2021.pdf',
#  'EXACT Sciences Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_EXAS_2021.pdf',
#  'Exlservice Holdings, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_EXLS_2021.pdf',
#  'Expeditors International of Washington': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_EXPD_2021.pdf',
#  'Extreme Networks, Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_EXTR_2021.pdf',
#  'Farmer Brothers Co.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_FARM_2021.pdf',
#  'Fifth Third Bancorp': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_FITB_2021.pdf',
#  'First Financial Bancorp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_FFBC_2021.pdf',
#  'First Hawaiian, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_FHB_2021.pdf',
#  'First Solar, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/f/NASDAQ_FSLR_2021.pdf',
#  'Fiserv Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_FISV_2021.pdf',
#  'Flex Ltd. ': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/f/NASDAQ_FLEX_2021.pdf',
#  'FLIR Systems Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_FLIR_2021.pdf',
#  'FLSmidth': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_FLS_2021.pdf',
#  'Fox Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/f/NASDAQ_FOX_2021.pdf',
#  'Franklin Electric Co. Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/f/NASDAQ_FELE_2021.pdf',
#  'Frontdoor, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/f/NASDAQ_FTDR_2021.pdf',
#  'Galapagos NV': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_GLPG_2021.pdf',
#  'Garmin Ltd.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_GRMN_2021.pdf',
#  'GDS Holdings Limited': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_GDS_2021.pdf',
#  'Genmab A/S': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_GMAB_2021.pdf',
#  'Gentex Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/g/NASDAQ_GNTX_2021.pdf',
#  'Gentherm Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_THRM_2021.pdf',
#  'Gibraltar Industries, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/g/NASDAQ_ROCK_2021.pdf',
#  'Gilead Sciences': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_GILD_2021.pdf',
#  'GlobalFoundries': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/g/NASDAQ_GFS_2021.pdf',
#  'Golden Ocean Group Ltd': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_GOGL_2021.pdf',
#  'Google Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/g/NASDAQ_GOOG_2021.pdf',
#  'Great Lakes Dredge & Dock Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_GLDD_2021.pdf',
#  'Green Plains Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_GPRE_2021.pdf',
#  'Gulfport Energy Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_GPOR_2021.pdf',
#  'Hancock Whitney Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_HWC_2021.pdf',
#  'Hawaiian Holdings, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/h/NASDAQ_HA_2021.pdf',
#  'Hawkins Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/h/NASDAQ_HWKN_2021.pdf',
#  'Henry Schein Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_HSIC_2021.pdf',
#  'Hologic Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_HOLX_2021.pdf',
#  'Hostess Brands, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_TWNK_2021.pdf',
#  'Huron Consulting Group Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_HURN_2021.pdf',
#  'ICF International Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_ICFI_2021.pdf',
#  'IDEXX Laboratories, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_IDXX_2021.pdf',
#  'Illumina Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/i/NASDAQ_ILMN_2021.pdf',
#  'Infinera Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_INFN_2021.pdf',
#  'Innospec Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_IOSP_2021.pdf',
#  'Insight Enterprises, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/i/NASDAQ_NSIT_2021.pdf',
#  'Intel Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_INTC_2021.pdf',
#  'Intuit Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/i/NASDAQ_INTU_2021.pdf',
#  'Intuitive Surgical, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_ISRG_2021.pdf',
#  'Iridium Communications Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_IRDM_2021.pdf',
#  'Itron, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_ITRI_2021.pdf',
#  'JetBlue Airways Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_JBLU_2021.pdf',
#  'Juniper Networks Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_JNPR_2021.pdf',
#  'Kaiser Aluminum Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_KALU_2021.pdf',
#  'Kelly Services Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_KELYA_2021.pdf',
#  'Keurig Dr Pepper': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NYSE_DPS_2021.pdf',
#  'Kforce Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_KFRC_2021.pdf',
#  'Kimball Electronics': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/k/NASDAQ_KE_2021.pdf',
#  'Kimball International Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_KBAL_2021.pdf',
#  'KLA-Tencor Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_KLAC_2021.pdf',
#  'Kulicke & Soffa Industries Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_KLIC_2021.pdf',
#  'Lam Research Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_LRCX_2021.pdf',
#  'Landec Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_LNDC_2021.pdf',
#  'Lattice Semiconductor Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_LSCC_2021.pdf',
#  "Leslie's": 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_LESL_2021.pdf',
#  'Liberty Global Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_LBTYA_2021.pdf',
#  'LKQ Corp.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_LKQ_2021.pdf',
#  'LM Ericsson Telephone Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/l/NASDAQ_ERIC_2021.pdf',
#  'Logitech International SA': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_LOGI_2021.pdf',
#  'LPL Financial Holding': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_LPLA_2021.pdf',
#  'Lululemon Athletica Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_LULU_2021.pdf',
#  'Lyft Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/l/NASDAQ_LYFT_2021.pdf',
#  'MarketAxess Holdings Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MKTX_2021.pdf',
#  'Marriott International, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/m/NASDAQ_MAR_2021.pdf',
#  'Matthews International Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MATW_2021.pdf',
#  'Maxim Integrated Products Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MXIM_2021.pdf',
#  'Medpace Holdings, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MEDP_2021.pdf',
#  'MercadoLibre, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MELI_2021.pdf',
#  'Merit Medical Systems Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MMSI_2021.pdf',
#  'Meta Platforms, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_FB_2021.pdf',
#  'Methanex Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/m/NASDAQ_MEOH_2021.pdf',
#  'MGE Energy Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MGEE_2021.pdf',
#  'Microchip Technology Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MCHP_2021.pdf',
#  'Microsoft Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MSFT_2021.pdf',
#  'Middlesex Water Company': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MSEX_2021.pdf',
#  'Mirati Therapeutics, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/m/NASDAQ_MRTX_2021.pdf',
#  'Mondelez International': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MDLZ_2021.pdf',
#  'Mylan Nv': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_MYL_2021.pdf',
#  'Nasdaq OMX Group Inc': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_NDAQ_2021.pdf',
#  'National Vision Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_EYE_2021.pdf',
#  'NetApp, Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_NTAP_2021.pdf',
#  'Netgear Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_NTGR_2021.pdf',
#  'Neurocrine Biosciences Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_NBIX_2021.pdf',
#  'Northern Trust': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_NTRS_2021.pdf',
#  'NortonLifeLock Inc.': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/n/NASDAQ_NLOK_2021.pdf',
#  'Norwegian Cruise Line Holdings Ltd': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_NCLH_2021.pdf',
#  'Nuance Communications': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReports/PDF/NASDAQ_NUAN_2021.pdf',
#  'NVIDIA Corporation': 'https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/n/NASDAQ_NVDA_2021.pdf',
#  ...}

# %%
#make a dataframe with reports and urls

report_bank_df_1255 = pd.DataFrame(columns=['name'], data=report_bank.keys())

# %%
report_bank_df_1255['ticker'] = tick_bank_list

# %%
report_bank_df_1255['url'] = report_bank.values()

# %%
report_bank_df_1255
# Out:
#                               name ticker  \
# 0                   3M Corporation    MMM
# 1                          ABB Ltd    ABB
# 2              Abbott Laboratories    ABT
# 3                       Abbvie Inc   ABBV
# 4             ABM Industries, Inc.    ABM
# ...                            ...    ...
# 1250                 Whitbread plc    WTB
# 1251  Wm Morrison Supermarkets plc    MRW
# 1252                       WPP PLC    WPP
# 1253                 WSP Group plc    WSH
# 1254               X5 Retail Group   FIVE
#
#                                                     url
# 0     https://www.responsibilityreports.com/HostedDa...
# 1     https://www.responsibilityreports.com/HostedDa...
# 2     https://www.responsibilityreports.com/HostedDa...
# 3     https://www.responsibilityreports.com/HostedDa...
# 4     https://www.responsibilityreports.com/HostedDa...
# ...                                                 ...
# 1250  https://www.responsibilityreports.com/HostedDa...
# 1251  https://www.responsibilityreports.com/HostedDa...
# 1252  https://www.responsibilityreports.com/HostedDa...
# 1253  https://www.responsibilityreports.com/HostedDa...
# 1254  https://www.responsibilityreports.com/HostedDa...
#
# [1255 rows x 3 columns]

# %%
df_report_bank = joblib.dump(report_bank_df_1255,'../data/df_report_bank.pkl')

# %% [markdown]
# We now have a dataframe which contains 1255 companies and their associated 2021 ESG report links.

# %% [markdown]
# ### Raw Text Extraction

# %% [markdown]
# The raw text needs to be extracted from the pdfs so that it can be used for the upcoming project. Two different packages were trialled for this - `pyPDF2` and `pdftotext`. The latter was preferred as it was much better at retaining a similar paragraph structure and order to the original pdf.

# %% [markdown]
# The following code is commented due to a lengthy run time. Advised to use the pickle below!

# %%
# df = joblib.load('../data/df_report_bank.pkl')

# %%
# df_li = []
# data = []
# dict = {}
# tick_ind = 0
# c = 0

# #iterate through the urls for each report
# for i in df['url']:
#    try:
#       url = i
#       file_list = []
#       tick = df.iloc[tick_ind,1]
#       #sector = df.iloc[tick_ind,0]

#       #convert pdf to raw txt
#       raw_text = cuf.pdf_to_raw_text(url)

#       #split text into paragraphs
#       raw_text = raw_text.split('\n\n')

#       # replacing any new line characters within a string with a space
#       raw_text = [x.replace('\n',' ') for x in raw_text]

#       # remove any strings which have less than 10 words (headers etc and thus just noise)
#       raw_text = [x for x in raw_text if len(x.split())>10]

        #iterate through the paragraphs and add the ticker, sector and paragraph to a list 'data'.
#       for para in raw_text:
#          res = (tick,sector,para)
#          data.append(res)

#       print(c)
#       c+=1
#       tick_ind +=1
#    except Exception as e:
#       print(e)
#       print(f'Error with {i}')
#       tick_ind +=1
#       c+=1

# %%
# joblib.dump(data,'../data/raw_text_data_1200.pkl')

# %%
data = joblib.load('../data/raw_text_data_1200.pkl')

# %% [markdown]
# The data in the list now needs to be converted to a dataframe.

# %%
col1 = []
col2 = []
for tup in data:
    col1.append(tup[0])
    col2.append(tup[2])

col1_df = pd.DataFrame(col1)
col1_df.rename(columns = {0:'ticker'},inplace=True)

col2_df = pd.DataFrame(col2)
col2_df.rename(columns = {0:'raw_paras'},inplace=True)

df_raw = col1_df
df_raw = pd.concat([df_raw,col2_df],axis=1)

df_raw.nunique()
# Out:
# ticker         1056
# raw_paras    344074
# dtype: int64

# %%
df_raw
# Out:
#        ticker                                          raw_paras
# 0         MMM  Growing our business by enabling action and im...
#  ...
#  ...
# 3         MMM  Mike Roman The last year has brought extraordi...
# 4         MMM  The pandemic has reinforced the importance of ...
# ...       ...                                                ...
# 371195   FIVE  • The planet: Our approach and 2021 highlights...
# 371196   FIVE  Goal 15. Protect, restore and promote sustaina...
# 371197   FIVE  • 15.2 By 2020, promote the implementation of ...
# 371198   FIVE  • The planet: Reduced climate impact and energ...
# 371199   FIVE  • 14.2 By 2020, sustainably manage and protect...
#
# [371200 rows x 2 columns]

# %% [markdown]
# We are now in a position where the 1200 reports have been split by paragraph, with each row in the above dataframe a raw paragraph.

# %% [markdown]
# ### Cleaning Text

# %% [markdown]
# The raw paragraphs now need to be cleaned. The process shown below is the refined process. This has been achived through an interative process to understand what stages of cleaning needed to be included. Ultimately, the cleaning process is condensed into a simple function `my_cleaner()` in the capstone_utility_functions.py. The main stages of the cleaning process are summarised below:
#
# * removes \n characters within lines
# * splits apart camel case
# * removes any numbers
# * lowercase words
# * remove any punctuation
# * remove any unicode
# * split string into individual tokens
# * remove stopwords
# * remove Parts of Speech which are not nouns
# * lemmatize tokens
# * stem tokens
# * remove any tokens less than a certain length
# * remove any tokens which are in a predefined list of unwanted words
#
# Note that the default for all options is set to true, apart from stemming, lemmatization and part of speech removal.
#
# An example test string is shown below to quickly demonstrate what the function does.

# %%
test = 'thisIS a 12Messy 3435 test and .ad.* need to see \n how the cleaning PROCESS works and splitsCamelCase ifNeeds'
cuf.my_cleaner(test,3, lemmatization=True,nouns=True)
# Out:
# ['test', 'need', 'process', 'split', 'case', 'need']

# %% [markdown]
# We now need to apply this to the dataframe containing raw paragraphs. Note the below block is commented out as it takes a while to run. It is recommended you load the pickle below.

# %%
# df_paras = df_raw.copy()
# # list of noisy words identified through the iterative process
# noisy = ['clients','west','percent','letter','sustainability','report','appendix','management','team','social','corporate','responsibility','business','pages','introduction']

# # feed the raw paragraphs into the custom cleaner. Note that tokens less than 3 letters long are treated as noise and removed.
# df_paras['clean_paras'] = [cuf.my_cleaner(x,3,noisy_words = noisy, newLineRemove = True,lemmatization=True,nouns = True,) for x in df_paras.raw_paras]
# df_paras

# %%
# joblib.dump(df_paras, '../data/clean_paras_df.pkl')

# %%
df_paras = joblib.load('../data/clean_paras_df.pkl')

# %%
df_paras
# Out:
#        ticker                                          raw_paras  \
# 0         MMM  Growing our business by enabling action and im...
#  ...
#  ...
# 3         MMM  Mike Roman The last year has brought extraordi...
# 4         MMM  The pandemic has reinforced the importance of ...
# ...       ...                                                ...
# 371195   FIVE  • The planet: Our approach and 2021 highlights...
# 371196   FIVE  Goal 15. Protect, restore and promote sustaina...
# 371197   FIVE  • 15.2 By 2020, promote the implementation of ...
# 371198   FIVE  • The planet: Reduced climate impact and energ...
# 371199   FIVE  • 14.2 By 2020, sustainably manage and protect...
#
#                                               clean_paras
# 0                   [action, impact, humanity, challenge]
# 1                 [content, leadership, message, message]
# 2            [health, safety, material, energy, supplier]
# 3       [mike, roman, year, challenge, time, recommit,...
# 4              [pandemic, importance, science, challenge]
# ...                                                   ...
# 371195  [planet, approach, highlight, packaging, impac...
# 371196  [goal, protect, restore, promote, forest, dese...
# 371197  [implementation, type, halt, deforestation, re...
# 371198  [planet, impact, energy, efficiency, consumption]
# 371199  [manage, marine, impact, resilience, action, r...
#
# [371200 rows x 3 columns]

# %% [markdown]
# We now have reports from 1200 companies, split by paragraph, with each paragraph cleaned and tokenised. EDA is the next stage of the pipeline.
