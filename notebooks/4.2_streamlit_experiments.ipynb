# %%
import pandas as pd
import altair as alt
import seaborn as sns
import plotly.express as px
import clean_pdf as cp
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import nltk.corpus
from nltk.corpus import stopwords
import string
import re
import requests
import pdftotext
import io
import subprocess
import joblib
import numpy as np
import gensim 
from gensim import corpora
import pyLDAvis.gensim_models
from sklearn.preprocessing import MinMaxScaler
import capstone_utility_functions as cuf
# Out:
# /Users/henryparemain/Documents/private_capstone/notebooks/capstone_utility_functions.py:219: DeprecationWarning: invalid escape sequence \{
#   document1 = re.sub(f"\{punc}", '', document)
# /Users/henryparemain/opt/anaconda3/envs/Capstone/lib/python3.7/site-packages/plac_ext.py:6: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp

# %%
url = 'https://www.tesla.com/ns_videos/2021-tesla-impact-report.pdf'
from tika import parser

try:
    parsed_pdf = parser.from_file(url)
except Exception as e:
    print(f"Exception occurred: {e}")
    exit()

# Extract text
pdf_text = parsed_pdf['content']
# Out:
# 2023-04-16 22:27:31,765 [MainThread  ] [INFO ]  Retrieving https://www.tesla.com/ns_videos/2021-tesla-impact-report.pdf to /var/folders/6g/n6mk7qn52n9dhnw8hy9rx6500000gn/T/ns_videos-2021-tesla-impact-report.pdf.

# %%
print(pdf_text)
# Out:
# Tesla 2021 Impact Report
#
#
# 1
#
#
#
# 2
#
# Foreword on Impact
#
# Current ESG evaluation
# methodologies are
# fundamentally flawed. To
# achieve acutely-needed
# change, ESG needs to
# evolve to measure real-
# world Impact.
#
# What ESG measures today: Investment Risk
#
# Current environmental, social and governance (ESG)
# reporting does not measure the scope of positive impact
# on the world. Instead, it focuses on measuring the dollar
# value of risk / return.
#
# Individual investors – who entrust their money to ESG
# funds of large investment institutions – are perhaps
# unaware that their money can be used to buy shares of
# companies that make climate change worse, not better.
#
# An obvious example of this is measuring the impact of the
# automotive industry. One might think that the more electric
# vehicles an automaker sells, as a percentage of total
# volumes, the better its ESG score. However, this is not the
# ...

# %%
pdf_text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTesla 2021 Impact Report\n\n\n1\n\n\n\n2\n\nForeword on Impact\n\nCurrent ESG evaluation \nmethodologies are \nfundamentally flawed. To \nachieve acutely-needed \nchange, ESG needs to \nevolve to measure real-\nworld Impact.\n\nWhat ESG measures today: Investment Risk\n\nCurrent environmental, social and governance (ESG) \nreporting does not measure the scope of positive impact \non the world. Instead, it focuses on measuring the dollar \nvalue of risk / return.\n\nIndividual investors – who entrust their money to ESG \nfunds of large investment institutions – are perhaps \nunaware that their money can be used to buy shares of \ncompanies that make climate change worse, not better.\n\nAn obvious example of this is measuring the impact of the \nautomotive industry. One might think that the more electric \nvehicles an automaker sells, as a percentage of total \
# ...

# %%
pdf_text = re.sub(r'[•]\s+', '\n\n', pdf_text)

# %%
print(pdf_text)
# Out:
# Tesla 2021 Impact Report
#
#
# 1
#
#
#
# 2
#
# Foreword on Impact
#
# Current ESG evaluation
# methodologies are
# fundamentally flawed. To
# achieve acutely-needed
# change, ESG needs to
# evolve to measure real-
# world Impact.
#
# What ESG measures today: Investment Risk
#
# Current environmental, social and governance (ESG)
# reporting does not measure the scope of positive impact
# on the world. Instead, it focuses on measuring the dollar
# value of risk / return.
#
# Individual investors – who entrust their money to ESG
# funds of large investment institutions – are perhaps
# unaware that their money can be used to buy shares of
# companies that make climate change worse, not better.
#
# An obvious example of this is measuring the impact of the
# automotive industry. One might think that the more electric
# vehicles an automaker sells, as a percentage of total
# volumes, the better its ESG score. However, this is not the
# ...

# %%
pdf_text = pdf_text.split('\n\n')

# %%
pdf_text
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '\nTesla 2021 Impact Report',
#  '\n1',
#  '',
#  '2',
#  'Foreword on Impact',
#  'Current ESG evaluation \nmethodologies are \nfundamentally flawed. To \nachieve acutely-needed \nchange, ESG needs to \nevolve to measure real-\nworld Impact.',
#  'What ESG measures today: Investment Risk',
#  'Current environmental, social and governance (ESG) \nreporting does not measure the scope of positive impact \non the world. Instead, it focuses on measuring the dollar \nvalue of risk / return.',
#  'Individual investors – who entrust their money to ESG \nfunds of large investment institutions – are perhaps \nunaware that their money can be used to buy shares of \ncompanies that make climate change worse, not better.',
# ...

# %%
pdf_text = [x.replace('\n',' ') for x in pdf_text]

# %%
pdf_text
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' Tesla 2021 Impact Report',
#  ' 1',
#  '',
#  '2',
#  'Foreword on Impact',
#  'Current ESG evaluation  methodologies are  fundamentally flawed. To  achieve acutely-needed  change, ESG needs to  evolve to measure real- world Impact.',
#  'What ESG measures today: Investment Risk',
#  'Current environmental, social and governance (ESG)  reporting does not measure the scope of positive impact  on the world. Instead, it focuses on measuring the dollar  value of risk / return.',
#  'Individual investors – who entrust their money to ESG  funds of large investment institutions – are perhaps  unaware that their money can be used to buy shares of  companies that make climate change worse, not better.',
# ...

# %%
print(modified_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tesla 2021 Impact Report
#
# 1
#
#
# 2
# Foreword on Impact
# Current ESG evaluation  methodologies are  fundamentally flawed. To  achieve acutely-needed  change, ESG needs to  evolve to measure real- world Impact.
# What ESG measures today: Investment Risk
# Current environmental, social and governance (ESG)  reporting does not measure the scope of positive impact  on the world. Instead, it focuses on measuring the dollar  value of risk / return.
# Individual investors – who entrust their money to ESG  funds of large investment institutions – are perhaps  unaware that their money can be used to buy shares of  companies that make climate change worse, not better.
# ...

# %%
modified_text = re.sub(r'(?<!\n)\n', ' ', modified_text)

# %%
print(modified_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tesla 2021 Impact Report
# 1
#
# ...

# %%
# test = test.replace('\n',' ')
modified_text = modified_text.split('\n\n')

# %%
modified_text
# Out:
# ['  ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '\nTesla 2021 Impact Report  \n1  ',
# ...

# %%
raw_text = cuf.pdf_to_raw_text('https://www.tesla.com/ns_videos/2021-tesla-impact-report.pdf')

# %%
print(raw_text)
# Out:
# 1
#
#
#
# Foreword on Impact
#
# What ESG measures today: Investment Risk
#
# What ESG needs to become: Company Impact
#
# Current ESG evaluation
# methodologies are
# fundamentally flawed. To
# achieve acutely-needed
# change, ESG needs to
# evolve to measure realworld Impact.
#
# Current environmental, social and governance (ESG)
# reporting does not measure the scope of positive impact
# on the world. Instead, it focuses on measuring the dollar
# value of risk / return.
#
# We need to create a system that measures and scrutinizes
# actual positive impact on our planet, so unsuspecting
# individual investors can choose to support companies that
# can make and prioritize positive change.
#
# Individual investors – who entrust their money to ESG
# funds of large investment institutions – are perhaps
# unaware that their money can be used to buy shares of
# companies that make climate change worse, not better.
#
# On the product front, companies should be required to use
# ...

# %%
test= '\n\nWhat ESG measures today: Investment Risk\n\nWhat ESG needs to become: Company Impact\n\nCurrent ESG evaluation\nmethodologies are\nfundamentally flawed. To\nachieve acutely-needed\nchange, ESG needs to\nevolve to measure realworld Impact.\n\nCurrent environmental, social and governance (ESG)\nreporting does not measure the scope of positive impact\non the world. Instead, it focuses on measuring the dollar\nvalue of risk / return.\n\nWe need to create a system that measures and scrutinizes\nactual'

# %%
# test = test.replace('\n',' ')
test = test.split('\n\n')

# %%
[x.replace('\n',' ') for x in test]
# Out:
# ['',
#  'What ESG measures today: Investment Risk',
#  'What ESG needs to become: Company Impact',
#  'Current ESG evaluation methodologies are fundamentally flawed. To achieve acutely-needed change, ESG needs to evolve to measure realworld Impact.',
#  'Current environmental, social and governance (ESG) reporting does not measure the scope of positive impact on the world. Instead, it focuses on measuring the dollar value of risk / return.',
#  'We need to create a system that measures and scrutinizes actual']

# %%
test
# Out:
# '  What ESG measures today: Investment Risk  What ESG needs to become: Company Impact  Current ESG evaluation methodologies are fundamentally flawed. To achieve acutely-needed change, ESG needs to evolve to measure realworld Impact.  Current environmental, social and governance (ESG) reporting does not measure the scope of positive impact on the world. Instead, it focuses on measuring the dollar value of risk / return.  We need to create a system that measures and scrutinizes actual'

# %%
#split text into paragraphs
raw_text = raw_text.split('\n\n')
raw_text = [x.replace('\n',' ') for x in raw_text]
# remove any strings which have less than 10 words (headers etc and thus just noise)
# raw_text = [x for x in raw_text if len(x.split())>10]

# %%
raw_text
# Out:
# ['1',
#  '\x0c',
#  'Foreword on Impact',
#  'What ESG measures today: Investment Risk',
#  'What ESG needs to become: Company Impact',
#  'Current ESG evaluation methodologies are fundamentally flawed. To achieve acutely-needed change, ESG needs to evolve to measure realworld Impact.',
#  'Current environmental, social and governance (ESG) reporting does not measure the scope of positive impact on the world. Instead, it focuses on measuring the dollar value of risk / return.',
#  'We need to create a system that measures and scrutinizes actual positive impact on our planet, so unsuspecting individual investors can choose to support companies that can make and prioritize positive change.',
#  'Individual investors – who entrust their money to ESG funds of large investment institutions – are perhaps unaware that their money can be used to buy shares of companies that make climate change worse, not better.',
# ...

# %%
df = pd.DataFrame(data=raw_text)

# %%
df.rename(columns={0:'raw_text'},inplace=True)

# %%
less_than_10 = df[df['raw_text'].apply(lambda x: len(x.split()))==13]

# %%
print([x for x in less_than_10.raw_text.sample(5)])
# Out:
# ['Discussion of strategy for managing fleet fuel economy and emissions risks and opportunities', 'operational use were categorized as ‘other’, for which only CO2 emissions are calculated,', 'Description of the management of risks associated with the use of critical materials', 'The quantity of manufacturing scrap processed was collected from Tesla’s cell recycling plant', 'Attendees of a first aid training organized by the FCA in the DRC']

# %%
pdf_data = io.BytesIO(uploaded_file.read())

# Convert the result from bytes to a string and display it to the user
text = result.stdout.decode("utf-8")
df = cp.clean_pdf(text)
  # load in pretrained lda model for 3 topics
lda_model = joblib.load('./data/3_topics_1200_reports_lda_model.pkl
#initialise empty dataframe to store probabilities in
a = np.empty((df.shape[0],3))
a[:] = np.nan
df_probs = pd.DataFrame(columns=['S','G','E'], data=
# iterate through clean paras and score the paragraph
for index, row in df.iterrows():
    #get the topic probabilities
    test_bow = lda_model.id2word.doc2bow(df.clean_paras[index])
    res = lda_model[test_bow]
    #append probabilities to the df_probs
    for i in res:
        row_num = index
        col_num = i[0]
        probability = i[1]
        df_probs.iloc[row_num, col_num] = probability
df_probs = pd.concat([df[['raw_paras','clean_paras']],df_probs],axis=1)
df_probs = df_probs[df_probs['clean_paras'].apply(lambda x: len(x))>5]
df_scores = df_probs[['S','G','E']]
#drop any missing values to be safe
df_scores = df_scores.dropna()
#identify threshold for outliers
p99_e = np.percentile(df_scores['E'], 9
# remove outliers
df_scores_outliers_rem = df_scores[df_scores["E"] <= p99_
#identify threshold for outliers
p99_s = np.percentile(df_scores['S'], 99)
# remove outliers
df_scores_outliers_rem = df_scores_outliers_rem[df_scores_outliers_rem["S"] <= p99_
#identify threshold for outliers
p99_g = np.percentile(df_scores['G'], 99)
# remove outliers
df_scores_outliers_rem = df_scores_outliers_rem[df_scores_outliers_rem["G"] <= p99_
# applying min_max scaler to scores
scaler = MinMaxScaler()
df_scores_fin= scaler.fit_transform(df_scores_outliers_rem)
df_scores_fin = pd.DataFrame(df_scores_fin,columns=df_scores.columns)
# Out:
#   Cell In[1], line 4
#     text = result.stdout.decode("utf-8")
#     ^
# IndentationError: unexpected indent

# %%
 top3e = greater_than_10.sort_values('E',ascending=False)
            st.subheader('Most Important Environmental Related Paragraph:')
            for i in list(range(0,selected_number)):
                st.write(top3e.iloc[i,0])
